# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
# Difference between your scores and correct scores:
# 3.68027207103e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b2 max relative error: 4.447677e-11
# b1 max relative error: 2.738421e-09
# W1 max relative error: 3.669857e-09
# W2 max relative error: 3.440708e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
input_size = 32 * 32 * 3
hidden_size = [30, 50, 70]
num_classes = 10
batch_size = [128, 256, 512]
learning_rate = [1e-5, 1e-4, 1e-3]
num_iters = [800, 1000, 1200]
reg = [0.1, 0.3, 0.5]
best_net = None
best_score = 0
case = 0
for hd_size in hidden_size:
    for bt_size in batch_size:
        for lr in learning_rate:
            for it in num_iters:
                for rg in reg:
                    print('##################### Case', case, '#####################')
                    net = TwoLayerNet(input_size, hd_size, num_classes)

# Train the network
                    stats = net.train(X_train, y_train, X_val, y_val,num_iters=it, batch_size=bt_size,
                                        learning_rate=lr, learning_rate_decay=0.95, reg=rg, verbose=False)

# Predict on the validation set
                    val_acc = (net.predict(X_val) == y_val).mean()
                    
                    print('Hidden size:', hd_size, '; batch_size:', bt_size, '; Learning rate:', lr, '; num_iters:', 
                         it, '; reg:', rg)
                    if val_acc > best_score:
                        best_score = val_acc
                        best_net = net
                    case += 1
                    print('Validation accuracy: ', val_acc)
                    print('Best accuracy so far:', best_score)
print('best val:', best_score)

#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# ##################### Case 0 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.192
# Best accuracy so far: 0.192
# ##################### Case 1 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.198
# Best accuracy so far: 0.198
# ##################### Case 2 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.174
# Best accuracy so far: 0.198
# ##################### Case 3 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.203
# Best accuracy so far: 0.203
# ##################### Case 4 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.183
# Best accuracy so far: 0.203
# ##################### Case 5 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.22
# Best accuracy so far: 0.22
# ##################### Case 6 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.179
# Best accuracy so far: 0.22
# ##################### Case 7 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.222
# Best accuracy so far: 0.222
# ##################### Case 8 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.204
# Best accuracy so far: 0.222
# ##################### Case 9 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.256
# Best accuracy so far: 0.256
# ##################### Case 10 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.262
# Best accuracy so far: 0.262
# ##################### Case 11 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.27
# Best accuracy so far: 0.27
# ##################### Case 12 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.284
# Best accuracy so far: 0.284
# ##################### Case 13 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.287
# Best accuracy so far: 0.287
# ##################### Case 14 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.284
# Best accuracy so far: 0.287
# ##################### Case 15 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.305
# Best accuracy so far: 0.305
# ##################### Case 16 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.306
# Best accuracy so far: 0.306
# ##################### Case 17 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.32
# Best accuracy so far: 0.32
# ##################### Case 18 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.42
# Best accuracy so far: 0.42
# ##################### Case 19 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.438
# Best accuracy so far: 0.438
# ##################### Case 20 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.448
# Best accuracy so far: 0.448
# ##################### Case 21 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.453
# Best accuracy so far: 0.453
# ##################### Case 22 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.425
# Best accuracy so far: 0.453
# ##################### Case 23 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.448
# Best accuracy so far: 0.453
# ##################### Case 24 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.466
# Best accuracy so far: 0.466
# ##################### Case 25 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.461
# Best accuracy so far: 0.466
# ##################### Case 26 #####################
# Hidden size: 30 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.446
# Best accuracy so far: 0.466
# ##################### Case 27 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.232
# Best accuracy so far: 0.466
# ##################### Case 28 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.177
# Best accuracy so far: 0.466
# ##################### Case 29 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.199
# Best accuracy so far: 0.466
# ##################### Case 30 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.219
# Best accuracy so far: 0.466
# ##################### Case 31 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.191
# Best accuracy so far: 0.466
# ##################### Case 32 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.176
# Best accuracy so far: 0.466
# ##################### Case 33 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.168
# Best accuracy so far: 0.466
# ##################### Case 34 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.217
# Best accuracy so far: 0.466
# ##################### Case 35 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.218
# Best accuracy so far: 0.466
# ##################### Case 36 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.264
# Best accuracy so far: 0.466
# ##################### Case 37 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.261
# Best accuracy so far: 0.466
# ##################### Case 38 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.27
# Best accuracy so far: 0.466
# ##################### Case 39 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.283
# Best accuracy so far: 0.466
# ##################### Case 40 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.292
# Best accuracy so far: 0.466
# ##################### Case 41 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.293
# Best accuracy so far: 0.466
# ##################### Case 42 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.309
# Best accuracy so far: 0.466
# ##################### Case 43 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.291
# Best accuracy so far: 0.466
# ##################### Case 44 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.32
# Best accuracy so far: 0.466
# ##################### Case 45 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.451
# Best accuracy so far: 0.466
# ##################### Case 46 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.449
# Best accuracy so far: 0.466
# ##################### Case 47 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.453
# Best accuracy so far: 0.466
# ##################### Case 48 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.465
# Best accuracy so far: 0.466
# ##################### Case 49 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.453
# Best accuracy so far: 0.466
# ##################### Case 50 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.474
# Best accuracy so far: 0.474
# ##################### Case 51 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.462
# Best accuracy so far: 0.474
# ##################### Case 52 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.472
# Best accuracy so far: 0.474
# ##################### Case 53 #####################
# Hidden size: 30 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.468
# Best accuracy so far: 0.474
# ##################### Case 54 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.217
# Best accuracy so far: 0.474
# ##################### Case 55 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.172
# Best accuracy so far: 0.474
# ##################### Case 56 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.186
# Best accuracy so far: 0.474
# ##################### Case 57 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.211
# Best accuracy so far: 0.474
# ##################### Case 58 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.225
# Best accuracy so far: 0.474
# ##################### Case 59 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.241
# Best accuracy so far: 0.474
# ##################### Case 60 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.216
# Best accuracy so far: 0.474
# ##################### Case 61 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.228
# Best accuracy so far: 0.474
# ##################### Case 62 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.2
# Best accuracy so far: 0.474
# ##################### Case 63 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.262
# Best accuracy so far: 0.474
# ##################### Case 64 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.268
# Best accuracy so far: 0.474
# ##################### Case 65 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.264
# Best accuracy so far: 0.474
# ##################### Case 66 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.287
# Best accuracy so far: 0.474
# ##################### Case 67 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.29
# Best accuracy so far: 0.474
# ##################### Case 68 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.288
# Best accuracy so far: 0.474
# ##################### Case 69 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.303
# Best accuracy so far: 0.474
# ##################### Case 70 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.317
# Best accuracy so far: 0.474
# ##################### Case 71 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.295
# Best accuracy so far: 0.474
# ##################### Case 72 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.446
# Best accuracy so far: 0.474
# ##################### Case 73 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.459
# Best accuracy so far: 0.474
# ##################### Case 74 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.471
# Best accuracy so far: 0.474
# ##################### Case 75 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.467
# Best accuracy so far: 0.474
# ##################### Case 76 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.475
# Best accuracy so far: 0.475
# ##################### Case 77 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.473
# Best accuracy so far: 0.475
# ##################### Case 78 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.485
# Best accuracy so far: 0.485
# ##################### Case 79 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.475
# Best accuracy so far: 0.485
# ##################### Case 80 #####################
# Hidden size: 30 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.467
# Best accuracy so far: 0.485
# ##################### Case 81 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.231
# Best accuracy so far: 0.485
# ##################### Case 82 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.219
# Best accuracy so far: 0.485
# ##################### Case 83 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.236
# Best accuracy so far: 0.485
# ##################### Case 84 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.208
# Best accuracy so far: 0.485
# ##################### Case 85 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.214
# Best accuracy so far: 0.485
# ##################### Case 86 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.208
# Best accuracy so far: 0.485
# ##################### Case 87 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.239
# Best accuracy so far: 0.485
# ##################### Case 88 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.226
# Best accuracy so far: 0.485
# ##################### Case 89 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.228
# Best accuracy so far: 0.485
# ##################### Case 90 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.269
# Best accuracy so far: 0.485
# ##################### Case 91 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.271
# Best accuracy so far: 0.485
# ##################### Case 92 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.271
# Best accuracy so far: 0.485
# ##################### Case 93 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.282
# Best accuracy so far: 0.485
# ##################### Case 94 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.29
# Best accuracy so far: 0.485
# ##################### Case 95 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.307
# Best accuracy so far: 0.485
# ##################### Case 96 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.323
# Best accuracy so far: 0.485
# ##################### Case 97 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.309
# Best accuracy so far: 0.485
# ##################### Case 98 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.315
# Best accuracy so far: 0.485
# ##################### Case 99 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.439
# Best accuracy so far: 0.485
# ##################### Case 100 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.476
# Best accuracy so far: 0.485
# ##################### Case 101 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.463
# Best accuracy so far: 0.485
# ##################### Case 102 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.477
# Best accuracy so far: 0.485
# ##################### Case 103 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.454
# Best accuracy so far: 0.485
# ##################### Case 104 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.467
# Best accuracy so far: 0.485
# ##################### Case 105 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.456
# Best accuracy so far: 0.485
# ##################### Case 106 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.455
# Best accuracy so far: 0.485
# ##################### Case 107 #####################
# Hidden size: 50 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.459
# Best accuracy so far: 0.485
# ##################### Case 108 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.212
# Best accuracy so far: 0.485
# ##################### Case 109 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.224
# Best accuracy so far: 0.485
# ##################### Case 110 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.227
# Best accuracy so far: 0.485
# ##################### Case 111 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.227
# Best accuracy so far: 0.485
# ##################### Case 112 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.211
# Best accuracy so far: 0.485
# ##################### Case 113 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.231
# Best accuracy so far: 0.485
# ##################### Case 114 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.226
# Best accuracy so far: 0.485
# ##################### Case 115 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.183
# Best accuracy so far: 0.485
# ##################### Case 116 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.257
# Best accuracy so far: 0.485
# ##################### Case 117 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.273
# Best accuracy so far: 0.485
# ##################### Case 118 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.269
# Best accuracy so far: 0.485
# ##################### Case 119 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.272
# Best accuracy so far: 0.485
# ##################### Case 120 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.292
# Best accuracy so far: 0.485
# ##################### Case 121 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.295
# Best accuracy so far: 0.485
# ##################### Case 122 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.291
# Best accuracy so far: 0.485
# ##################### Case 123 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.325
# Best accuracy so far: 0.485
# ##################### Case 124 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.312
# Best accuracy so far: 0.485
# ##################### Case 125 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.326
# Best accuracy so far: 0.485
# ##################### Case 126 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.462
# Best accuracy so far: 0.485
# ##################### Case 127 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.462
# Best accuracy so far: 0.485
# ##################### Case 128 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.456
# Best accuracy so far: 0.485
# ##################### Case 129 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.479
# Best accuracy so far: 0.485
# ##################### Case 130 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.479
# Best accuracy so far: 0.485
# ##################### Case 131 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.455
# Best accuracy so far: 0.485
# ##################### Case 132 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.484
# Best accuracy so far: 0.485
# ##################### Case 133 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.465
# Best accuracy so far: 0.485
# ##################### Case 134 #####################
# Hidden size: 50 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.467
# Best accuracy so far: 0.485
# ##################### Case 135 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.211
# Best accuracy so far: 0.485
# ##################### Case 136 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.219
# Best accuracy so far: 0.485
# ##################### Case 137 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.233
# Best accuracy so far: 0.485
# ##################### Case 138 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.243
# Best accuracy so far: 0.485
# ##################### Case 139 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.197
# Best accuracy so far: 0.485
# ##################### Case 140 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.19
# Best accuracy so far: 0.485
# ##################### Case 141 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.21
# Best accuracy so far: 0.485
# ##################### Case 142 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.23
# Best accuracy so far: 0.485
# ##################### Case 143 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.209
# Best accuracy so far: 0.485
# ##################### Case 144 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.262
# Best accuracy so far: 0.485
# ##################### Case 145 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.272
# Best accuracy so far: 0.485
# ##################### Case 146 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.268
# Best accuracy so far: 0.485
# ##################### Case 147 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.286
# Best accuracy so far: 0.485
# ##################### Case 148 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.294
# Best accuracy so far: 0.485
# ##################### Case 149 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.294
# Best accuracy so far: 0.485
# ##################### Case 150 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.321
# Best accuracy so far: 0.485
# ##################### Case 151 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.315
# Best accuracy so far: 0.485
# ##################### Case 152 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.31
# Best accuracy so far: 0.485
# ##################### Case 153 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.476
# Best accuracy so far: 0.485
# ##################### Case 154 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.48
# Best accuracy so far: 0.485
# ##################### Case 155 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.465
# Best accuracy so far: 0.485
# ##################### Case 156 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.48
# Best accuracy so far: 0.485
# ##################### Case 157 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.477
# Best accuracy so far: 0.485
# ##################### Case 158 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.475
# Best accuracy so far: 0.485
# ##################### Case 159 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.479
# Best accuracy so far: 0.485
# ##################### Case 160 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.495
# Best accuracy so far: 0.495
# ##################### Case 161 #####################
# Hidden size: 50 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.492
# Best accuracy so far: 0.495
# ##################### Case 162 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.239
# Best accuracy so far: 0.495
# ##################### Case 163 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.205
# Best accuracy so far: 0.495
# ##################### Case 164 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.221
# Best accuracy so far: 0.495
# ##################### Case 165 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.214
# Best accuracy so far: 0.495
# ##################### Case 166 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.24
# Best accuracy so far: 0.495
# ##################### Case 167 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.202
# Best accuracy so far: 0.495
# ##################### Case 168 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.239
# Best accuracy so far: 0.495
# ##################### Case 169 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.217
# Best accuracy so far: 0.495
# ##################### Case 170 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.229
# Best accuracy so far: 0.495
# ##################### Case 171 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.275
# Best accuracy so far: 0.495
# ##################### Case 172 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.281
# Best accuracy so far: 0.495
# ##################### Case 173 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.271
# Best accuracy so far: 0.495
# ##################### Case 174 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.308
# Best accuracy so far: 0.495
# ##################### Case 175 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.298
# Best accuracy so far: 0.495
# ##################### Case 176 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.298
# Best accuracy so far: 0.495
# ##################### Case 177 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.316
# Best accuracy so far: 0.495
# ##################### Case 178 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.32
# Best accuracy so far: 0.495
# ##################### Case 179 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.325
# Best accuracy so far: 0.495
# ##################### Case 180 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.478
# Best accuracy so far: 0.495
# ##################### Case 181 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.47
# Best accuracy so far: 0.495
# ##################### Case 182 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.459
# Best accuracy so far: 0.495
# ##################### Case 183 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.483
# Best accuracy so far: 0.495
# ##################### Case 184 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.474
# Best accuracy so far: 0.495
# ##################### Case 185 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.469
# Best accuracy so far: 0.495
# ##################### Case 186 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.478
# Best accuracy so far: 0.495
# ##################### Case 187 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.466
# Best accuracy so far: 0.495
# ##################### Case 188 #####################
# Hidden size: 70 ; batch_size: 128 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.476
# Best accuracy so far: 0.495
# ##################### Case 189 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.243
# Best accuracy so far: 0.495
# ##################### Case 190 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.211
# Best accuracy so far: 0.495
# ##################### Case 191 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.208
# Best accuracy so far: 0.495
# ##################### Case 192 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.221
# Best accuracy so far: 0.495
# ##################### Case 193 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.239
# Best accuracy so far: 0.495
# ##################### Case 194 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.27
# Best accuracy so far: 0.495
# ##################### Case 195 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.247
# Best accuracy so far: 0.495
# ##################### Case 196 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.225
# Best accuracy so far: 0.495
# ##################### Case 197 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.247
# Best accuracy so far: 0.495
# ##################### Case 198 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.28
# Best accuracy so far: 0.495
# ##################### Case 199 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.279
# Best accuracy so far: 0.495
# ##################### Case 200 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.28
# Best accuracy so far: 0.495
# ##################### Case 201 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.3
# Best accuracy so far: 0.495
# ##################### Case 202 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.294
# Best accuracy so far: 0.495
# ##################### Case 203 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.294
# Best accuracy so far: 0.495
# ##################### Case 204 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.327
# Best accuracy so far: 0.495
# ##################### Case 205 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.317
# Best accuracy so far: 0.495
# ##################### Case 206 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.328
# Best accuracy so far: 0.495
# ##################### Case 207 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.483
# Best accuracy so far: 0.495
# ##################### Case 208 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.465
# Best accuracy so far: 0.495
# ##################### Case 209 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.461
# Best accuracy so far: 0.495
# ##################### Case 210 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.485
# Best accuracy so far: 0.495
# ##################### Case 211 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.478
# Best accuracy so far: 0.495
# ##################### Case 212 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.475
# Best accuracy so far: 0.495
# ##################### Case 213 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.497
# Best accuracy so far: 0.497
# ##################### Case 214 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.474
# Best accuracy so far: 0.497
# ##################### Case 215 #####################
# Hidden size: 70 ; batch_size: 256 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.471
# Best accuracy so far: 0.497
# ##################### Case 216 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.237
# Best accuracy so far: 0.497
# ##################### Case 217 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.225
# Best accuracy so far: 0.497
# ##################### Case 218 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.199
# Best accuracy so far: 0.497
# ##################### Case 219 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.231
# Best accuracy so far: 0.497
# ##################### Case 220 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.226
# Best accuracy so far: 0.497
# ##################### Case 221 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.203
# Best accuracy so far: 0.497
# ##################### Case 222 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.22
# Best accuracy so far: 0.497
# ##################### Case 223 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.183
# Best accuracy so far: 0.497
# ##################### Case 224 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 1e-05 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.261
# Best accuracy so far: 0.497
# ##################### Case 225 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.281
# Best accuracy so far: 0.497
# ##################### Case 226 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.273
# Best accuracy so far: 0.497
# ##################### Case 227 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.276
# Best accuracy so far: 0.497
# ##################### Case 228 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.299
# Best accuracy so far: 0.497
# ##################### Case 229 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.3
# Best accuracy so far: 0.497
# ##################### Case 230 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.293
# Best accuracy so far: 0.497
# ##################### Case 231 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.327
# Best accuracy so far: 0.497
# ##################### Case 232 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.33
# Best accuracy so far: 0.497
# ##################### Case 233 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.0001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.326
# Best accuracy so far: 0.497
# ##################### Case 234 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.1
# Validation accuracy:  0.479
# Best accuracy so far: 0.497
# ##################### Case 235 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.3
# Validation accuracy:  0.484
# Best accuracy so far: 0.497
# ##################### Case 236 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 800 ; reg: 0.5
# Validation accuracy:  0.471
# Best accuracy so far: 0.497
# ##################### Case 237 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.1
# Validation accuracy:  0.486
# Best accuracy so far: 0.497
# ##################### Case 238 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.3
# Validation accuracy:  0.478
# Best accuracy so far: 0.497
# ##################### Case 239 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1000 ; reg: 0.5
# Validation accuracy:  0.495
# Best accuracy so far: 0.497
# ##################### Case 240 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.1
# Validation accuracy:  0.476
# Best accuracy so far: 0.497
# ##################### Case 241 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.3
# Validation accuracy:  0.505
# Best accuracy so far: 0.505
# ##################### Case 242 #####################
# Hidden size: 70 ; batch_size: 512 ; Learning rate: 0.001 ; num_iters: 1200 ; reg: 0.5
# Validation accuracy:  0.491
# Best accuracy so far: 0.505
# best val: 0.505
# best model:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-87bc50f66d54> in <module>()
#      49 print('best model:',)
#      50 for key in best_net.params:
# ---> 51     print(key, ':', best_net[key])
#      52
#      53
#
# TypeError: 'TwoLayerNet' object is not subscriptable

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.494
